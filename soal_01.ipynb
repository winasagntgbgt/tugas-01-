# %% [markdown]
# <a href="https://colab.research.google.com/github/winasagntgbgt/tugas-01-/blob/main/soal_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nilai = []  # array kosong untuk menyimpan nilai

print("Masukkan 10 nilai mahasiswa:")
for i in range(10):
    n = float(input(f"Nilai ke-{i+1}: "))
    nilai.append(n)

# Tampilkan semua nilai
print("\nData nilai:", nilai)

# 2. Nilai tertinggi & terendah
nilai_tertinggi = max(nilai)
nilai_terendah = min(nilai)

print("Nilai tertinggi:", nilai_tertinggi)
print("Nilai terendah:", nilai_terendah)

# 3. Rata-rata
rata_rata = sum(nilai) / len(nilai)
print("Rata-rata:", rata_rata)

# 4. Hitung jumlah mahasiswa lulus (>= 60)
jumlah_lulus = 0
for n in nilai:
    if n >= 60:
        jumlah_lulus += 1

print("Jumlah mahasiswa lulus:", jumlah_lulus)

# 5 & 6. Grafik
import matplotlib.pyplot as plt

# Grafik nilai tertinggi & terendah
plt.figure()
plt.bar(["Tertinggi", "Terendah"], [nilai_tertinggi, nilai_terendah])
plt.title("Perbandingan Nilai Tertinggi & Terendah")
plt.show()

# Grafik kelulusan
tidak_lulus = len(nilai) - jumlah_lulus

plt.figure()
plt.pie([jumlah_lulus, tidak_lulus], labels=["Lulus", "Tidak Lulus"], autopct="%1.1f%%")
plt.title("Persentase Kelulusan")
plt.show()
# Out:
# Masukkan 10 nilai mahasiswa:
# Nilai ke-1: 10
# Nilai ke-2: 20
# Nilai ke-3: 30
# Nilai ke-4: 47
# Nilai ke-5: 39
# Nilai ke-6: 80
# Nilai ke-7: 95
# Nilai ke-8: 20
# Nilai ke-9: 85
# Nilai ke-10: 75
#
# Data nilai: [10.0, 20.0, 30.0, 47.0, 39.0, 80.0, 95.0, 20.0, 85.0, 75.0]
# Nilai tertinggi: 95.0
# Nilai terendah: 10.0
# Rata-rata: 50.1
# Jumlah mahasiswa lulus: 4
